# %% [markdown]
# ## 有理数復元
#
# ### 参考
#
# - [rational reconstruction の解説をしようかな - えびちゃんの日記](https://rsk0315.hatenablog.com/entry/2023/04/29/043512)
# - [Rational reconstruction - wikipedia](https://en.wikipedia.org/wiki/Rational_reconstruction_(mathematics))

# %%
import math
import random

# %%
def rational_reconstruction(x: int, m: int) -> tuple[int, int]:
    """有理数を復元する"""
    N = D = math.sqrt(m // 2)
    v = (m, 0)
    w = (x, 1)
    while w[0] > N:
        q = v[0] // w[0]
        z = (v[0] - q * w[0], v[1] - q * w[1])
        v = w
        w = z
    if w[0] < N and w[1] < D:
        if w[1] < 0:
            w = -w[0], -w[1]
        return w
    else:
        return None

# %% [markdown]
# ### ランダムテスト

# %%
def generate_random_fraction(m: int):
    """法mにおけるランダムな分数を作る"""
    n = random.randint(-1000, 1000)
    d = random.randint(-1000, 1000)
    if d == 0:
        return generate_random_fraction(m)
    G = math.gcd(n, d)
    n, d = n // G, d // G
    if d < 0:
        n, d = -n, -d
    x = (m + n) * pow(d, -1, m) % m
    return (n, d), x

# %%
MOD = 998244353

# %%
for _ in range(100):
    (n, d), x = generate_random_fraction(MOD)
    p, q = rational_reconstruction(x, MOD)

    assert (n, d) == (p, q)

    print(f"{(n, d)} -> {p, q}: {x}")
# Out:
# (353, 319) -> (353, 319): 491298946
# (-293, 185) -> (-293, 185): 544987456
# (92, 617) -> (92, 617): 694079137
# (223, 216) -> (223, 216): 670117738
# (-62, 13) -> (-62, 13): 383940131
# (19, 47) -> (19, 47): 637177247
# (212, 87) -> (212, 87): 780236968
# (-37, 43) -> (-37, 43): 69644954
# (-713, 708) -> (-713, 708): 695105177
# (-92, 61) -> (-92, 61): 670951121
# (-212, 141) -> (-212, 141): 134515195
# (-287, 297) -> (-287, 297): 618440945
# (71, 399) -> (71, 399): 260194017
# (294, 883) -> (294, 883): 749531151
# (-18, 139) -> (-18, 139): 588892352
# (-57, 508) -> (-57, 508): 898026908
# (-657, 547) -> (-657, 547): 319365194
# (72, 553) -> (72, 553): 451285874
# (819, 517) -> (819, 517): 347551227
# (830, 531) -> (830, 531): 877928651
# (-728, 865) -> (-728, 865): 889764619
# (-149, 497) -> (-149, 497): 580468044
# (-27, 28) -> (-27, 28): 962592768
# (398, 103) -> (398, 103): 455509563
# (-148, 171) -> (-148, 171): 379449607
# (-733, 438) -> (-733, 438): 640426170
# (-59, 426) -> (-59, 426): 241359550
# (-318, 859) -> (-318, 859): 589184967
# (-152, 973) -> (-152, 973): 694564673
# (-454, 235) -> (-454, 235): 12743543
# (337, 884) -> (337, 884): 771267979
# (-311, 133) -> (-311, 133): 180134317
# (-359, 233) -> (-359, 233): 466989846
# (403, 252) -> (403, 252): 289173961
# (-45, 136) -> (-45, 136): 330301440
# (-823, 610) -> (-823, 610): 132553757
# (416, 825) -> (416, 825): 245628611
# (-951, 668) -> (-951, 668): 572346686
# (-472, 27) -> (-472, 27): 739440244
# (-623, 676) -> (-623, 676): 104845190
# (-794, 53) -> (-794, 53): 828731146
# (199, 36) -> (199, 36): 360477133
# (119, 5) -> (119, 5): 399297765
# (-351, 967) -> (-351, 967): 771136020
# (-380, 327) -> (-380, 327): 644127089
# (-562, 215) -> (-562, 215): 691806549
# (485, 622) -> (485, 622): 855408747
# (363, 547) -> (363, 547): 443461386
# (-982, 103) -> (-982, 103): 862560645
# (58, 189) -> (58, 189): 987680921
# (-234, 289) -> (-234, 289): 632106285
# (119, 31) -> (119, 31): 354215742
# (23, 40) -> (23, 40): 224604980
# (207, 170) -> (207, 170): 182032795
# (-566, 343) -> (-566, 343): 608259677
# (-719, 270) -> (-719, 270): 380811732
# (-203, 859) -> (-203, 859): 498541126
# (989, 728) -> (989, 728): 26053082
# (-269, 263) -> (-269, 263): 478246343
# (853, 500) -> (853, 500): 996247866
# (959, 55) -> (959, 55): 308548272
# (-592, 289) -> (-592, 289): 165798368
# (-667, 285) -> (-667, 285): 784585033
# (650, 737) -> (650, 737): 212651783
# (-31, 348) -> (-31, 348): 169242577
# (95, 154) -> (95, 154): 563943239
# (-38, 267) -> (-38, 267): 351441832
# (99, 196) -> (99, 196): 921848102
# (-121, 39) -> (-121, 39): 51192015
# (349, 292) -> (349, 292): 215374639
# (455, 608) -> (455, 608): 776594703
# (-929, 838) -> (-929, 838): 992288240
# (-323, 317) -> (-323, 317): 185793112
# (598, 107) -> (598, 107): 634398286
# (481, 752) -> (481, 752): 380978896
# (-923, 511) -> (-923, 511): 709124656
# (526, 545) -> (526, 545): 628252869
# (-18, 131) -> (-18, 131): 373389109
# (229, 73) -> (229, 73): 834149394
# (-77, 269) -> (-77, 269): 723634382
# (479, 665) -> (479, 665): 468349231
# (-20, 79) -> (-20, 79): 897156317
# (-628, 331) -> (-628, 331): 916816564
# (-475, 68) -> (-475, 68): 983564282
# (437, 392) -> (437, 392): 28011960
# (-159, 47) -> (-159, 47): 552220277
# (-454, 75) -> (-454, 75): 905074874
# (-607, 220) -> (-607, 220): 721458416
# (-2, 163) -> (-2, 163): 594047253
# (793, 165) -> (793, 165): 750195761
# (445, 753) -> (445, 753): 931959868
# (-32, 223) -> (-32, 223): 67146481
# (25, 193) -> (25, 193): 56894756
# (762, 565) -> (762, 565): 726156513
# (-992, 379) -> (-992, 379): 942932658
# (212, 309) -> (212, 309): 743029778
# (-904, 107) -> (-904, 107): 419822383
# (-371, 263) -> (-371, 263): 622479367
# (985, 792) -> (985, 792): 8822868
# (-47, 146) -> (-47, 146): 485447596
